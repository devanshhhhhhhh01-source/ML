# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\anaconda\DATASET\Module-5-Data-Sets\Iris (1).csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.plot(kind = 'scatter', x = 'SepalLengthCm', y = 'SepalWidthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.jointplot(x = 'SepalLengthCm', y = 'SepalWidthCm', data = df, size = 5)

# %%
sns.FacetGrid(df, hue = 'Species') \
.map(plt.scatter, 'SepalLengthCm', 'SepalWidthCm')\
.\
add_legend()


plt.show()

# %%
sns.boxplot(x = 'Species', y = 'PetalLengthCm', data = df)
plt.show()

# %%
ax = sns.boxplot(x = 'Species', y = 'PetalLengthCm', data = df)
ax = sns.stripplot(x = 'Species', y = 'PetalLengthCm', data = df, jitter = True, edgecolor = 'black')

# %%
sns.violinplot(x = 'Species', y = 'PetalLengthCm', data = df)
plt.show()

# %%
g = sns.FacetGrid(df, hue = 'Species')
g.map(sns.kdeplot, 'PetalLengthCm').add_legend()
plt.show()

# %%
sns.pairplot(df.drop('Id', axis = 1), hue = 'Species', size = 3)
plt.show()
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df.drop('Id', axis = 1), hue = 'Species', size = 3, diag_kind = 'hist')
plt.show()
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.drop('Id', axis = 1).boxplot(by = 'Species', figsize = (12,16))
plt.show()

# %%
from pandas.plotting import andrews_curves

andrews_curves(df.drop('Id', axis = 1), 'Species')
plt.show()

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates(df.drop('Id', axis = 1), 'Species')
plt.show()

# %%
from pandas.plotting import radviz
radviz(df.drop('Id', axis = 1), 'Species')
plt.show()
